# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\w5429064\Downloads\DA_Data\diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Glucose']= df['Glucose'].replace(0,df['Glucose'].mean())

# %%
df['BloodPressure']= df['BloodPressure'].replace(0,df['BloodPressure'].mean())

df['SkinThickness']= df['SkinThickness'].replace(0,df['SkinThickness'].mean())

df['Insulin']= df['Insulin'].replace(0,df['Insulin'].mean())

df['BMI']= df['BMI'].replace(0,df['BMI'].mean())

# %%
df.groupby(['Pregnancies']).count()
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Pregnancies
# 0                111            111            111      111  111
# 1                135            135            135      135  135
# 2                103            103            103      103  103
# 3                 75             75             75       75   75
# 4                 68             68             68       68   68
# 5                 57             57             57       57   57
# 6                 50             50             50       50   50
# 7                 45             45             45       45   45
# 8                 38             38             38       38   38
# 9                 28             28             28       28   28
# 10                24             24             24       24   24
# 11                11             11             11       11   11
# 12                 9              9              9        9    9
# ...

# %%
fig, ax = plt.subplots()
ax.bar(df['Age'],df['Glucose'])
ax.set_xlabel('Age')
ax.set_ylabel('Glucose')
ax.set_title('Bar Chart Example')
# Out:
# Text(0.5, 1.0, 'Bar Chart Example')

# %%
fig, ax = plt.subplots()
ax.hist(df['Age'])
ax.set_title('Bar Chart Example')
# Out:
# Text(0.5, 1.0, 'Bar Chart Example')

# %%
fig, ax=  plt.subplots(figsize=(15,10))
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12f0cb18820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12f0cb18d60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12f0cb18580>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x12f0cb261c0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x12f0cb26460>,
# ...
#  'means': []}

# %%
fig, ax=  plt.subplots(figsize=(15,10))
sns.boxplot(data=df, width=0.9, ax=ax)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# <AxesSubplot: >

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
type(df[df[['Age', 'Insulin']].duplicated()])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['Age', 'Insulin']].duplicated())
# Out:
# pandas.core.series.Series

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.127964       0.208984       0.013376
# Glucose                      0.127964  1.000000       0.219666       0.160766
# BloodPressure                0.208984  0.219666       1.000000       0.134155
# SkinThickness                0.013376  0.160766       0.134155       1.000000
# Insulin                     -0.018082  0.396597       0.010926       0.240361
# BMI                          0.021546  0.231478       0.281231       0.535703
# DiabetesPedigreeFunction    -0.033523  0.137106       0.000371       0.154961
# Age                          0.544341  0.266600       0.326740       0.026423
# Outcome                      0.221898  0.492908       0.162986       0.175026
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018082  0.021546                 -0.033523
# ...

# %%
df['Age'].unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68], dtype=int64)
